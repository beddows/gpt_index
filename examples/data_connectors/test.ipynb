# %%
from gpt_index import GPTListIndex, SimpleWebPageReader
from IPython.display import Markdown, display
import os

# %%
documents = SimpleWebPageReader(html_to_text=True).load_data(
    ["https://docs.datarobot.com/en/docs/modeling/modeling-basics.html"])

# %%
print(documents)
# Out:
# [Document(text='Skip to content\n\n[ ![logo](../assets/images/logo.svg) ](/ "DataRobot docs")\n\n  * [ DataRobot University ](https://university.datarobot.com)\n  * [ Community ](https://community.datarobot.com)\n  * [ DataRobot.com ](https://www.datarobot.com)\n\n  * [ UI docs ](/en/ui)\n  * [ API docs ](/en/api)\n  * [ Platform ](/en/platform)\n  * [ Learn more ](/en/more-info)\n  * [ Releases ](/en/release)\n\n__\n\nClose\n\nNo result to preview.\n\n### Great! Let us know what you found helpful.\n\n### What can we do to improve the content?\n\nSubmit\n\n  * [ Data ](../data/index.html)\n  * [ Modeling ](index.html)\n  * [ Predictions ](../predictions/index.html)\n  * [ MLOps ](../mlops/index.html)\n  * [ DataRobot Notebooks ](../dr-notebooks/index.html)\n  * [ No-Code AI Apps ](../app-builder/index.html)\n\nClick __in-app to access the full platform documentation for your version of\nDataRobot.\n\n[ ![logo](../assets/images/logo.svg) ](/ "DataRobot docs") DataRobot docs\nModeling 
# ...

# %%
with open("sitemap_urls.dat", "r") as file:
    urls = file.read().splitlines()

print(urls)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_r/dspgzwzx46zg9srpjd7gn_b80000gn/T/ipykernel_48676/4143584377.py in <module>
# ----> 1 with open("sitemap_urls.dat", "r") as file:
#       2     urls = file.read().splitlines()
#       3
#       4 print(urls)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sitemap_urls.dat'

# %%
# !pwd
# Out:
# /Users/michaelbeddows/dev/gpt_index/examples/data_connectors

# %%
# !cd ../../../satya
# !pwd
# Out:
# /Users/michaelbeddows/dev/gpt_index/examples/data_connectors

# %%
# !cd ../../../satya

# %%
# !pwd
# Out:
# /Users/michaelbeddows/dev/gpt_index/examples/data_connectors
